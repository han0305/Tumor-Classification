# %%
#import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#getting data
data = pd.read_csv('data.csv')

# %%
#data
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# 'Unnamed: 32' consists of only missiong values
data['Unnamed: 32'].isnull().mean()
# Out:
# 1.0

# %%
# 'id' consists of all unique values
print(len(data))
print(len(data['id'].unique()))
# Out:
# 569
# 569

# %%
# only 'Unnamed: 32' contains missing value
data.isnull().mean()
# Out:
# id                         0.0
# diagnosis                  0.0
# radius_mean                0.0
# texture_mean               0.0
# perimeter_mean             0.0
# area_mean                  0.0
# smoothness_mean            0.0
# compactness_mean           0.0
# concavity_mean             0.0
# concave points_mean        0.0
# symmetry_mean              0.0
# fractal_dimension_mean     0.0
# radius_se                  0.0
# texture_se                 0.0
# perimeter_se               0.0
# area_se                    0.0
# smoothness_se              0.0
# compactness_se             0.0
# concavity_se               0.0
# concave points_se          0.0
# symmetry_se                0.0
# fractal_dimension_se       0.0
# radius_worst               0.0
# texture_worst              0.0
# perimeter_worst            0.0
# area_worst                 0.0
# smoothness_worst           0.0
# compactness_worst          0.0
# concavity_worst            0.0
# concave points_worst       0.0
# ...

# %%
# description of data
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#remove id,unamed:32 and diagnosis(target variable)
drop_list = ['id','diagnosis','Unnamed: 32']
target = 'diagnosis'
x = data.drop(drop_list,axis = 1)
y = data[target]

# %%
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean           ...             radius_worst  \
# ...

# %%
y.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
# checking for outliers
for var in x.columns:
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    fig = x.boxplot(column=var)
    fig.set_title('')
    fig.set_ylabel(var)
    
    plt.subplot(1, 2, 2)
    fig = x[var].hist(bins=20)
    fig.set_ylabel('Number')
    fig.set_xlabel(var)
 
    plt.show()

# %%
# skewed data
skewed_list = ['perimeter_mean','area_mean','compactness_mean','concavity_mean','concave points_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','concavity_se','fractal_dimension_se','radius_worst','perimeter_worst','area_worst','compactness_worst','concavity_worst']
gaussian_list  = [col for col in x.columns if col not in skewed_list]

# %%
print("skewed list-> {}".format(skewed_list))
print("gaussin list-> {}".format(gaussian_list))
# Out:
# skewed list-> ['perimeter_mean', 'area_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'concavity_se', 'fractal_dimension_se', 'radius_worst', 'perimeter_worst', 'area_worst', 'compactness_worst', 'concavity_worst']
# gaussin list-> ['radius_mean', 'texture_mean', 'smoothness_mean', 'symmetry_mean', 'compactness_se', 'concave points_se', 'symmetry_se', 'texture_worst', 'smoothness_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
print(len(skewed_list)+len(gaussian_list))
print(x.shape)
# Out:
# 30
# (569, 30)

# %%
#topcoding
cols = x.columns
for col in cols:
    if col in skewed_list:
        IQR = x[col].quantile(0.75) - x[col].quantile(0.25)
        Upper_fence = data[col].quantile(0.75) + (IQR * 3)
        x[col]=np.where(x[col]>Upper_fence,Upper_fence,x[col])
    else:
        Upper_boundary = data[col].mean() + 3* data[col].std()
        x[col]=np.where(x[col]>Upper_boundary,Upper_boundary,x[col])

# %%
x.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.109361     19.271460       91.969033   651.745870
# std       3.462910      4.234610       24.298981   338.371201
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      24.699438     32.192756      188.500000  1869.900000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096297          0.104308        0.088799             0.048919
# std           0.013829          0.052669        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
#correlation among variables
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(x.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
drop_list = ['perimeter_mean','radius_mean','compactness_mean','concave points_mean','radius_se','perimeter_se','radius_worst','perimeter_worst','compactness_worst','concave points_worst','compactness_se','concave points_se','texture_worst','area_worst']
x.drop(drop_list,inplace=True,axis = 1 ) 
x.head()
# Out:
#    texture_mean  area_mean  smoothness_mean  concavity_mean  symmetry_mean  \
# 0         10.38     1001.0         0.118400          0.3001         0.2419
# 1         17.77     1326.0         0.084740          0.0869         0.1812
# 2         21.25     1203.0         0.109600          0.1974         0.2069
# 3         20.38      386.1         0.138553          0.2414         0.2597
# 4         14.34     1297.0         0.100300          0.1980         0.1809
#
#    fractal_dimension_mean  texture_se  area_se  smoothness_se  concavity_se  \
# 0                 0.07871      0.9053   127.21       0.006399       0.05373
# 1                 0.05667      0.7339    74.08       0.005225       0.01860
# 2                 0.05999      0.7869    94.03       0.006150       0.03832
# 3                 0.09138      1.1560    27.23       0.009110       0.05661
# 4                 0.05883      0.7813    94.44       0.011490       0.05688
#
# ...

# %%
f,ax = plt.subplots(figsize=(18,18))
sns.heatmap(x.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
#splitting the data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 398
# 171
# 398
# 171

# %%
# importing packages
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
clf_rf = RandomForestClassifier(random_state=43)      
clr_rf = clf_rf.fit(x_train,y_train)

# %%
# feature selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
select_feature = SelectKBest(chi2, k=5).fit(x_train, y_train)

# %%
print('Score list:', select_feature.scores_)
print('Feature list:', x_train.columns)
# Out:
# Score list: [5.89940839e+01 3.52283449e+04 1.00577595e-01 1.30547650e+01
#  1.89797108e-01 3.45878797e-04 4.02147082e-02 4.69197798e+03
#  2.27333029e-03 8.19995565e-01 1.76069452e-04 4.87458178e-03
#  2.58530997e-01 2.58858117e+01 9.05847217e-01 1.16078410e-01]
# Feature list: Index(['texture_mean', 'area_mean', 'smoothness_mean', 'concavity_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'area_se',
#        'smoothness_se', 'concavity_se', 'symmetry_se', 'fractal_dimension_se',
#        'smoothness_worst', 'concavity_worst', 'symmetry_worst',
#        'fractal_dimension_worst'],
#       dtype='object')

# %%
x_train_2 = select_feature.transform(x_train)
x_test_2 = select_feature.transform(x_test)

clf_rf_2 = RandomForestClassifier(n_estimators=10,criterion='gini')      
clr_rf_2 = clf_rf_2.fit(x_train_2,y_train)
ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
print('Accuracy is: ',ac_2)
cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
sns.heatmap(cm_2,annot=True,fmt="d")
# Out:
# Accuracy is:  0.9707602339181286

# %%
#hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# %%
parameters = [{'n_estimators':[10,100,1000],'criterion':['gini']},{'n_estimators':[10,100,1000],'criterion':['entropy']}]

# %%
grid_search = GridSearchCV(estimator = clr_rf_2, param_grid = parameters, scoring = 'accuracy', cv=10)

# %%
grid_search = grid_search.fit(x_train_2,y_train)

# %%
best_score = grid_search.best_score_

# %%
best_score
# Out:
# 0.9170854271356784

# %%
best_parameters = grid_search.best_params_

# %%
best_parameters
# Out:
# {'criterion': 'gini', 'n_estimators': 10}
